# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
import nltk
from nltk.corpus import names
import random
from sklearn.metrics import precision_recall_fscore_support

# %%
keywords= ["access",
"act now!",
"apply now",
"apply online",
"call free",
"call now",
"can't live without",
"do it today",
"don't delete",
"don't hesitate",
"for instant access",
"for Only",
"for you",
"get it now",
"get started now",
"great offer",
"info you requested",
"information you requested",
"instant",
"limited time",
"new customers only",
"now",
"now only",
"offer expires",
"once in lifetime",
"one time",
"only",
"order now",
"order today",
"please read",
"special promotion",
"supplies are limited",
"take action now",
"time limited",
"urgent",
"while supplies last",
"free",
"cancel at any time",
"compare",
"copy accurately",
"get",
"give it away",
"print form signature",
"print out and fax",
"see for yourself",
"sign up free today",
"$$$",
"affordable",
"bargain",
"beneficiary",
"best price",
"big bucks",
"Cash",
"Cash bonus",
"Cashcashcash",
"Cents on the dollar",
"Cheap",
"Check",
"Claims",
"collect",
"compare rates",
"cost",
"credit",
"credit bureaus",
"discount",
"earn",
"easy terms",
"fast cash",
"for just $",
"hidden assets",
"hidden charges",
"income",
"incredible deal",
"insurance",
"investment",
"loans",
"lowest price",
"million dollars",
"money",
"money back",
"mortgage",
"mortgage rates",
"no cost",
"no fees",
"one hundred percent free",
"only $",
"pennies a day",
"price",
"profits",
"pure profit",
"quote",
"refinance",
"save $",
"save big money",
"save up to",
"serious cash",
"subject to credit",
"they keep your money — no refund!",
"unsecured credit",
"unsecured debt",
"US dollars",
"why pay more?"]
scam = ["Fraud","Phishing"]

# %%
df= pd.read_csv('phishing_data_by_type.csv')
df.head()
# Out:
#                                       Subject  \
# 0  URGENT BUSINESS ASSISTANCE AND PARTNERSHIP
# 1         URGENT ASSISTANCE /RELATIONSHIP (P)
# 2                             GOOD DAY TO YOU
# 3                            from Mrs.Johnson
# 4                                Co-Operation
#
#                                                 Text   Type
# 0  URGENT BUSINESS ASSISTANCE AND PARTNERSHIP.\n\...  Fraud
# 1  Dear Friend,\n\nI am Mr. Ben Suleman a custom ...  Fraud
# 2  FROM HIS ROYAL MAJESTY (HRM) CROWN RULER OF EL...  Fraud
# 3  Goodday Dear\n\n\nI know this mail will come t...  Fraud
# 4  FROM MR. GODWIN AKWESI\nTEL: +233 208216645\nF...  Fraud

# %%
def sus_words_search(sus_words, email):
    check = email.lower()
    res= any(ele in check for ele in sus_words)
    if res == 1 : return {'Scam': email[0] }
    else: return {'Not Scam': email[0] }
def ScamOrNot(words, scam_statues ):
    res= any(ele in scam_statues for ele in words)
    return res

#print(sus_words_search( keywords, "URGent longer" ))
#print(ScamOrNot( scam, 'Fraud longer word' ))

# %%
temp= df.Text.to_list()
temp1=df.Type.to_list()
#emails_text = zip(temp,temp1)
emails_text = [list(t) for t in zip(temp, temp1)]

# %%
featuresets = [(sus_words_search(keywords, ele1), ele2) for (ele1, ele2) in emails_text ]


train_set, test_set = train_test_split(featuresets)



classifier = nltk.NaiveBayesClassifier.train(train_set)

print(classifier)
# Out:
# <nltk.classify.naivebayes.NaiveBayesClassifier object at 0x000001AB3DF71070>

# %%
y_true = list(list(zip(*test_set))[1])

test_features = list(list(zip(*test_set))[0])

y_predict = [classifier.classify(features) for features in test_features]


(p,r,f,s) = precision_recall_fscore_support(y_true, y_predict)
print("p: ",p,"r: ",r,"f: ",f,s)
# Out:
# p:  [0.16666667 0.5        0.83333333 0.25      ] r:  [0.57142857 0.33333333 0.5        0.07142857] f:  [0.25806452 0.4        0.625      0.11111111] [ 7  9 10 14]
